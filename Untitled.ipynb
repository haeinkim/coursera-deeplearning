# %%
x = np.random.normal(loc=mean[label],
                            scale=scale,
                            size=size).reshape(2, -1)
x.shape
# Out:
# (2, 200)

# %%
D = np.array([])
X = np.random.normal(loc=0.25, 
                     scale=0.15, 
                     size=size).reshape(2, -1)
D = np.concatenate((X, D), axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-3c7251cb7353> in <module>()
#       3                      scale=0.15,
#       4                      size=size).reshape(2, -1)
# ----> 5 D = np.concatenate((X, D), axis=1)
#
# ValueError: all the input arrays must have same number of dimensions

# %%
import numpy as np
import matplotlib.pyplot as plt

n_labels = 2
n_features = 2
mean = [0.25, 0.75]
scale = 0.15
size = 400
planar = []
for label in range(n_labels):    
    X = np.random.normal(loc=mean[label], 
                         scale=scale, 
                         size=size).reshape(n_features, -1)
    planar.append(X)

planar[:0,: ]
    
#     theta = X * np.pi * 2
#     r = np.sin(4 * theta)

#     X[0] = r * np.cos(theta)
#     X[1] = r * np.sin(theta)
    
planar.shape
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-38-3fe568615aee> in <module>()
#      12                          scale=scale,
#      13                          size=size).reshape(n_features, -1)
# ---> 14     plannar = np.concatenate([planar, X], axis=1)
#      15
#      16 #     theta = X * np.pi * 2
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
mean = (0.25, 0.75)
cov = [[0.15, 0], [0, 0.15]]
size = 400
clsA = np.zeros((200, 1))
clsB = np.ones((200, 1))
X = np.random.multivariate_normal(mean, cov, size)
X1 = X[:, 0].reshape(2, -1)
X2 = X[:, 1].reshape(2, -1)
print(X1.shape, X2.shape)

y = np.concatenate((clsA, clsB), axis=0)
# x, y = make_blobs(n_samples=400, n_features=1, cluster_std=0.15, centers=[(0.25,), (0.75,)])

theta = X * np.pi * 2
r = np.sin(4 * theta)

X = r * np.cos(theta)

# x1 = r[:, 0] * np.cos(theta[:, 0])
# x2 = r[:, 1] * np.sin(theta[:, 1])

# X = np.concatenate((x1, x2), axis=1).reshape(2, -1)

print("The rose bloomed!")
print(X.shape, y.shape)
# Out:
# (2, 200) (2, 200)
# The rose bloomed!
# (400, 2) (400, 1)

# %%
X = np.random.multivariate_normal(mean, cov, size)
X.shape
x1 = np.mean(X[:, 0])
x2 = np.mean(X[:, 1])
print(x1, x2)
# Out:
# 0.240594573581 0.762684438891

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs


x, y = make_blobs(n_samples=400, n_features=1, cluster_std=0.15, centers=[(0.25,), (0.75,)])


theta = x * np.pi * 2 
r = np.sin(4 * theta)

x1 = r * np.cos(theta)
x2 = r * np.sin(theta)

X = np.concatenate((x1, x2), axis=1).reshape(2, -1)
print(X.shape)

plt.subplot(121)
plt.scatter(th, r, c=y)
plt.subplot(122)
plt.scatter(x1, x2, c=y)
plt.show()
# Out:
# (2, 400)

# %%
from planar import DataGenerator

generator = DataGenerator()

Xa = generator.planar_generator(0.5, 0.5, 200)

Xb = generator.planar_generator(1.5, 0.5, 200)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-155-1aaa5bed93d7> in <module>()
#       3 generator = DataGenerator()
#       4
# ----> 5 Xa = generator.planar_generator(0.5, 0.5, 200)
#       6
#       7 Xb = generator.planar_generator(1.5, 0.5, 200)
#
# TypeError: planar_generator() takes 3 positional arguments but 4 were given

# %%
X = np.concatenate((X1, X2), axis=0)
y = np.concatenate((np.zeros((200,1)), np.ones((200,1))), axis=1)

plt.scatter(X1, X2, c=y)
plt.show()
